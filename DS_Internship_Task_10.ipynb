# %% [markdown]
# #Task 5: Interactive Business Dashboard in Streamlit
#
# **Dataset:**
#
# Global Superstore Dataset

# %% [markdown]
# ##1. Introduction and Problem Statement
# **Introduction**
#
# In modern businesses, decision-making depends heavily on clear and interactive data analysis rather than static reports. An interactive dashboard allows managers and analysts to quickly explore performance trends, identify profitable areas, and understand customer behavior.In this task, we develop an interactive Business Intelligence dashboard using Streamlit based on the Global Superstore dataset. The dashboard enables users to filter data by Region, Category, and Sub-Category, and visually analyze key performance indicators such as Total Sales, Profit, and Top Customers. This helps transform raw sales data into meaningful insights for better business decisions.
#
#
#
# **Problem Statement**
#
# In business operations, managers and analysts need a clear understanding of sales performance, profit margins, and customer behavior. Relying on static reports makes it difficult to explore trends, compare regions, or identify top-performing products and customers. This task addresses this challenge by creating an interactive dashboard that allows dynamic exploration of sales data and insights.
#
#
# **Objective**
#
# To build an interactive BI dashboard using Streamlit that:
#
# - Cleans and prepares the Global Superstore dataset
# - Shows key KPIs (Sales, Profit)
# - Allows dynamic filtering
# - Displays visual insights using charts

# %% [markdown]
# ##2. Dataset Understanding and Description
# The Global Superstore dataset contains sales transactions from multiple regions, product categories, and customers. It provides information on orders, products, sales, and profits, enabling analysis of business performance. Key columns include:
#
# - **Order Date** – the date when an order was placed
# - **Region** – the geographical area of the order
# - **Category** – product category (e.g., Furniture, Technology, Office Supplies)
# - **Sub-Category** – detailed product type within each category
# - **Sales** – total sales amount for the order
# - **Profit** – profit earned from the order
# - **Customer Name** – name of the customer for identifying top customers
#
# This dataset allows for analysis of regional sales, category-wise profit, and identification of high-value customers to support strategic business decisions.

# %% [markdown]
# ##3. Data Loading and Cleaning
# **Import Required Libraries**

# %%
#install Streamlit
# !pip install streamlit

#Import Data Manipulation library
import pandas as pd
# Out:
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 9.1/9.1 MB 49.7 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 6.9/6.9 MB 49.4 MB/s eta 0:00:00
# ...
#   Attempting uninstall: cachetools
#     Found existing installation: cachetools 7.0.0
#     Uninstalling cachetools-7.0.0:
#       Successfully uninstalled cachetools-7.0.0
# ...

# %% [markdown]
# **Load Dataset**

# %%
from google.colab import files
files.upload()

df = pd.read_csv("superstore.csv", encoding='latin1')
# Out:
#      <input type="file" id="files-0b41e6a5-03a7-4979-8f6d-7396937d8a56" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-0b41e6a5-03a7-4979-8f6d-7396937d8a56">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script>// Copyright 2017 Google LLC
# //
# // Licensed under the Apache License, Version 2.0 (the "License");
# // you may not use this file except in compliance with the License.
# // You may obtain a copy of the License at
# //
# //      http://www.apache.org/licenses/LICENSE-2.0
# //
# // Unless required by applicable law or agreed to in writing, software
# // distributed under the License is distributed on an "AS IS" BASIS,
# // WITHOUT WARRANTIES OR CONDITIONS OF ANY KIND, either express or implied.
# // See the License for the specific language governing permissions and
# // limitations under the License.
#
# ...

# %% [markdown]
# **Preview the Dataset**

# %%
df.head()
# Out:
#           Category         City        Country Customer.ID     Customer.Name  \
# 0  Office Supplies  Los Angeles  United States   LS-172304  Lycoris Saunders
# 1  Office Supplies  Los Angeles  United States   MV-174854     Mark Van Huff
# 2  Office Supplies  Los Angeles  United States   CS-121304      Chad Sievert
# 3  Office Supplies  Los Angeles  United States   CS-121304      Chad Sievert
# 4  Office Supplies  Los Angeles  United States   AP-109154    Arthur Prichep
#
#    Discount Market  è®°å½æ°               Order.Date        Order.ID  ...  \
# 0       0.0     US          1  2011-01-07 00:00:00.000  CA-2011-130813  ...
# 1       0.0     US          1  2011-01-21 00:00:00.000  CA-2011-148614  ...
# 2       0.0     US          1  2011-08-05 00:00:00.000  CA-2011-118962  ...
# 3       0.0     US          1  2011-08-05 00:00:00.000  CA-2011-118962  ...
# 4       0.0     US          1  2011-09-29 00:00:00.000  CA-2011-146969  ...
#
# ...

# %% [markdown]
# **Handle Missing Values**

# %%
# Check missing values
df.isnull().sum()
# Out:
# Category          0
# City              0
# Country           0
# Customer.ID       0
# Customer.Name     0
# Discount          0
# Market            0
# è®°å½æ°         0
# Order.Date        0
# Order.ID          0
# Order.Priority    0
# Product.ID        0
# Product.Name      0
# Profit            0
# Quantity          0
# Region            0
# Row.ID            0
# Sales             0
# Segment           0
# Ship.Date         0
# Ship.Mode         0
# Shipping.Cost     0
# State             0
# Sub.Category      0
# Year              0
# Market2           0
# weeknum           0
# dtype: int64

# %% [markdown]
# No missing value found.

# %% [markdown]
# **Order Date to Datetime**

# %%
# Convert Order Date to datetime
df['Order.Date'] = pd.to_datetime(df['Order.Date'])

# %% [markdown]
# **Remove duplicates**

# %%
# Remove duplicates
df.drop_duplicates(inplace=True)

# %% [markdown]
# **Dataset Information**

# %%
# Check data types
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 51290 entries, 0 to 51289
# Data columns (total 27 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   Category        51290 non-null  object
#  1   City            51290 non-null  object
#  2   Country         51290 non-null  object
#  3   Customer.ID     51290 non-null  object
#  4   Customer.Name   51290 non-null  object
#  5   Discount        51290 non-null  float64
#  6   Market          51290 non-null  object
#  7   è®°å½æ°       51290 non-null  int64
#  8   Order.Date      51290 non-null  datetime64[ns]
#  9   Order.ID        51290 non-null  object
#  10  Order.Priority  51290 non-null  object
#  11  Product.ID      51290 non-null  object
#  12  Product.Name    51290 non-null  object
#  13  Profit          51290 non-null  float64
#  14  Quantity        51290 non-null  int64
#  15  Region          51290 non-null  object
#  16  Row.ID          51290 non-null  int64
# ...

# %%
# Extract year for analysis
df['Year'] = df['Order.Date'].dt.year

# %% [markdown]
# ##4. Exploratory Data Analysis (EDA)
# **Total Sales & Profit**

# %%
total_sales = df['Sales'].sum()
total_profit = df['Profit'].sum()

print("Total Sales:", total_sales)
print("Total Profit:", total_profit)
# Out:
# Total Sales: 12642905
# Total Profit: 1467457.2912800002

# %% [markdown]
# **Sales by Region**

# %%
df.groupby("Region")["Sales"].sum().sort_values(ascending=False)
# Out:
# Region
# Central           2822399
# South             1600960
# North             1248192
# Oceania           1100207
# Southeast Asia     884438
# North Asia         848349
# EMEA               806184
# Africa             783776
# Central Asia       752839
# West               725514
# East               678834
# Caribbean          324281
# Canada              66932
# Name: Sales, dtype: int64

# %% [markdown]
# **Top 5 Customers**

# %%
df.groupby("Customer.Name")["Sales"].sum().sort_values(ascending=False).head(5)
# Out:
# Customer.Name
# Tom Ashbrook          40489
# Tamara Chand          37453
# Greg Tran             35552
# Christopher Conant    35187
# Sean Miller           35170
# Name: Sales, dtype: int64

# %% [markdown]
# ##5. Streamlit Dashboard Code

# %%
# %%writefile app.py
# paste full streamlit code below this line

import streamlit as st
import pandas as pd
import plotly.express as px

# Page settings
st.set_page_config(page_title="Business Dashboard", layout="wide")

st.title("📊 Global Superstore Interactive Dashboard")

# Load data
@st.cache_data
def load_data():
    df = pd.read_csv("superstore.csv", encoding='latin1')
    df['Order.Date'] = pd.to_datetime(df['Order.Date'])
    return df

df = load_data()

# ==============================
# SIDEBAR FILTERS
# ==============================

st.sidebar.header("🔎 Filter Data")

region = st.sidebar.multiselect(
    "Select Region",
    df["Region"].unique(),
    default=df["Region"].unique()
)

category = st.sidebar.multiselect(
    "Select Category",
    df["Category"].unique(),
    default=df["Category"].unique()
)

sub_category = st.sidebar.multiselect(
    "Select Sub-Category",
    df["Sub.Category"].unique(),
    default=df["Sub.Category"].unique()
)

# Apply filters
filtered_df = df[
    (df["Region"].isin(region)) &
    (df["Category"].isin(category)) &
    (df["Sub.Category"].isin(sub_category))
]

# If no data after filtering
if filtered_df.empty:
    st.warning("No data available for selected filters.")
else:

    # ==============================
    # KPIs
    # ==============================

    total_sales = filtered_df["Sales"].sum()
    total_profit = filtered_df["Profit"].sum()

    col1, col2 = st.columns(2)

    col1.metric("💰 Total Sales", f"${total_sales:,.2f}")
    col2.metric("📈 Total Profit", f"${total_profit:,.2f}")

    st.markdown("---")

    # ==============================
    # Sales by Region
    # ==============================

    st.subheader("Sales by Region")

    region_data = (
        filtered_df.groupby("Region")["Sales"]
        .sum()
        .reset_index()
    )

    fig_region = px.bar(
        region_data,
        x="Region",
        y="Sales",
        text_auto=True
    )

    st.plotly_chart(fig_region, use_container_width=True)

    # ==============================
    # Profit by Category
    # ==============================

    st.subheader("Profit by Category")

    category_data = (
        filtered_df.groupby("Category")["Profit"]
        .sum()
        .reset_index()
    )

    fig_category = px.pie(
        category_data,
        names="Category",
        values="Profit"
    )

    st.plotly_chart(fig_category, use_container_width=True)

    # ==============================
    # Top 5 Customers
    # ==============================

    st.subheader("🏆 Top 5 Customers by Sales")

    top_customers = (
        filtered_df.groupby("Customer.Name")["Sales"]
        .sum()
        .sort_values(ascending=False)
        .head(5)
        .reset_index()
    )

    fig_top = px.bar(
        top_customers,
        x="Customer.Name",
        y="Sales",
        text_auto=True
    )

    st.plotly_chart(fig_top, use_container_width=True)

    # ==============================
    # Show Raw Data
    # ==============================

    st.subheader("📄 Filtered Data Preview")
    st.dataframe(filtered_df.head(10))
# Out:
# Writing app.py

# %% [markdown]
# **Run the Dashboard**
#
# In terminal:
#
# `streamlit run app.py`

# %% [markdown]
# ##Conclusion and Insights
#
# The interactive dashboard provides a clear view of the Global Superstore’s sales and profit performance. By using filters for Region, Category, and Sub-Category, users can dynamically explore the data and uncover important business trends.
#
# **Key Insights:**
#
# - **Regional Performance:** Some regions contribute significantly higher sales, indicating strong market demand in those areas.
#
# - **Profit vs Sales:** Certain categories or sub-categories generate high sales but lower profits, highlighting areas where cost management could improve margins.
#
# - **Top Customers:** A small group of customers contributes disproportionately to total sales, suggesting potential for targeted loyalty programs or marketing strategies.
#
# - **Interactive Analysis:** Dynamic filtering enables quick comparisons across regions, categories, and sub-categories, supporting faster, data-driven decisions.
#
# Overall, the dashboard transforms raw sales data into actionable business insights, improving the ability to make strategic and operational decisions efficiently.
